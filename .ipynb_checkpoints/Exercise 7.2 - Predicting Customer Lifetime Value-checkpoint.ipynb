# %% [markdown]
# # Predicting Customer Lifetime Value¶
# Using past purchasing history of customers to build a model that can predict the CLV for new customers

# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
import seaborn as sn

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
import sklearn.metrics

# %%
raw_data = pd.read_csv("history.csv")
raw_data.head(2)
# Out:
#    CUST_ID  MONTH_1  MONTH_2  MONTH_3  MONTH_4  MONTH_5  MONTH_6    CLV
# 0     1001      150       75      200      100      175       75  13125
# 1     1002       25       50      150      200      175      200   9375

# %%
raw_data.dtypes
# Out:
# CUST_ID    int64
# MONTH_1    int64
# MONTH_2    int64
# MONTH_3    int64
# MONTH_4    int64
# MONTH_5    int64
# MONTH_6    int64
# CLV        int64
# dtype: object

# %% [markdown]
# # Correlation Analysis

# %%
cleaned_data = raw_data.drop("CUST_ID", axis=1)
cleaned_data.head(2)
# Out:
#    MONTH_1  MONTH_2  MONTH_3  MONTH_4  MONTH_5  MONTH_6    CLV
# 0      150       75      200      100      175       75  13125
# 1       25       50      150      200      175      200   9375

# %%
#correlation of all columns to CLV, Show 5 Highest correlations.
cleaned_data.corr()['CLV'].nlargest(5,)
# Out:
# CLV        1.000000
# MONTH_1    0.734122
# MONTH_5    0.376775
# MONTH_3    0.371742
# MONTH_6    0.327064
# Name: CLV, dtype: float64

# %%
#Months are strongest correlation to the target variable (CLV).  Month 1 (73.4%), Month 5, Month 3, etc.
#Perfect correlation = 1, so strongest relationship is the highest value in month data. 
cleaned_data.corr()['CLV'].nlargest(5,).plot()
# Out:
# <AxesSubplot:>

# %%
#corr = cleaned_data.corr()['CLV']
f,ax = plt.subplots(figsize=(10,8))
corr = cleaned_data.corr()
sn.heatmap(corr,mask=np.zeros_like(corr, dtype=bool), cmap=sn.diverging_palette(200,110,as_cmap=True), square=True, ax=ax)
# Out:
# <AxesSubplot:>

# %%
#corr = cleaned_data.corr()['CLV']
sn.pairplot(cleaned_data[['CLV', 'MONTH_2', 'MONTH_1','MONTH_5']])
sn.lmplot(x="CLV", y="MONTH_1", data=cleaned_data);

# %%
sn.scatterplot(data = cleaned_data, x = "CLV", y = "MONTH_1")
#plot the line of best fit for highest correlation month.
sn.lmplot(x="CLV", y="MONTH_1", data=cleaned_data);
#plot the line of Best fit for lowest correlation month.
sn.lmplot(x="CLV", y="MONTH_6", data=cleaned_data);

# %% [markdown]
# # Do Training & Testing Split
# To perform supervised machine learning - need to split the data into training (80%) & testing (20%) datasets.

# %%
#Need to .Drop the Target column ('CLV') as a predictor.  
#Set Target as 'CLV' column. Training (.8) & testing (.2)

predictors = cleaned_data.drop(["CLV","MONTH_4"], axis=1)
targets = cleaned_data.CLV
pred_train, pred_test, tar_train, tar_test = train_test_split(predictors, targets, test_size=.3)
print( "Predictor - Training: ", pred_train.shape, "Predictor - testing: ", pred_test.shape)
# Out:
# Predictor - Training:  (70, 5) Predictor - testing:  (30, 5)

# %% [markdown]
# # Build a Linear Regression equation for predicting CLV and
# then check its accuracy against the test dataset.

# %%
#Build model on training data
model = LinearRegression()
model.fit(pred_train, tar_train)
print("Coefficients: \n", model.coef_)
print("Intercept: ", model.intercept_)


#test on testing data
predictions = model.predict(pred_test)
predictions

print("Accuracy of model:", sklearn.metrics.r2_score(tar_test, predictions).round(2))
#output shows the accuracy of the predicting CLV model is ?%.
# Out:
# Coefficients:
#  [33.6335006   9.58725529 15.28987593  8.86290776  4.72184722]
# Intercept:  1406.8132205921193
# Accuracy of model: 0.86

# %% [markdown]
# # Predicting the CLV for a new customer

# %%
#let's say new customer spends = first 6 months €100, 0, €50, €0, €0, €0.
#Use this model to predict this customer's CLV.

new_data = np.array([100,0, 50,0,0,0]).reshape(1,-1)
new_pred=model.predict(new_data)
print("The CLV for the new customer who bought only in first 3 months: €", new_pred[0].round(2))
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [70], in <cell line: 5>()
#       1 #let's say new customer spends = first 6 months €100, 0, €50, €0, €0, €0.
#       2 #Use this model to predict this customer's CLV.
#       4 new_data = np.array([100,0, 50,0,0,0]).reshape(1,-1)
# ----> 5 new_pred=model.predict(new_data)
#       6 print("The CLV for the new customer who bought only in first 3 months: €", new_pred[0].round(2))
#
# File C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_base.py:362, in LinearModel.predict(self, X)
#     348 def predict(self, X):
#     349     """
#     350     Predict using the linear model.
#     351
#    (...)
#     360         Returns predicted values.
#     361     """
# --> 362     return self._decision_function(X)
#
# File C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_base.py:345, in LinearModel._decision_function(self, X)
#     342 def _decision_function(self, X):
#     343     check_is_fitted(self)
# --> 345     X = self._validate_data(X, accept_sparse=["csr", "csc", "coo"], reset=False)
#     346     return safe_sparse_dot(X, self.coef_.T, dense_output=True) + self.intercept_
#
# File C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:585, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, **check_params)
#     582     out = X, y
#     584 if not no_val_X and check_params.get("ensure_2d", True):
# --> 585     self._check_n_features(X, reset=reset)
#     587 return out
#
# File C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:400, in BaseEstimator._check_n_features(self, X, reset)
#     397     return
#     399 if n_features != self.n_features_in_:
# --> 400     raise ValueError(
#     401         f"X has {n_features} features, but {self.__class__.__name__} "
#     402         f"is expecting {self.n_features_in_} features as input."
#     403     )
#
# ValueError: X has 6 features, but LinearRegression is expecting 5 features as input.

# %%
#let's say new customer spends = first 1 month €300, 0, €0, €0, €0, €0.
#Use this model to predict this customer's CLV.

second_data = np.array([300,0, 0,0,0,0]).reshape(1,-1)
second_pred=model.predict(second_data)
print("The CLV for the new customer who bought only €100 in first month: €", second_pred[0].round(2))

# %%
#Customer spends 300 in months 3 to 6 only. 
new_data = np.array([0,0,300,300,300,300]).reshape(1,-1)
new_pred=model.predict(new_data)
print("The CLV for the new customer who bought only in last 3-6 months: €", new_pred[0].round(2))

# %%
#Customer spends 0 in months 1 to 6. 
new_data = np.array([0,0,0,0,0,0]).reshape(1,-1)
new_pred=model.predict(new_data)
print("The CLV for the new customer who did not buy in first 6 months: €", new_pred[0].round(2))
