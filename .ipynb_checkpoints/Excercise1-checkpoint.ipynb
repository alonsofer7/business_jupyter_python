# %%
import pandas as pd
import numpy as np

#from pandas import Series, Dataframe

# %%
data = pd.read_csv('GFP_database.csv', encoding = 'latin1')

# %%
#To display the Dataframe called 'data' just type the name
data
# Out:
#       Area Abbreviation  Area Code         Area  Item Code  \
# 0                    AF          2  Afghanistan       2511
# 1                    AF          2  Afghanistan       2805
# 2                    AF          2  Afghanistan       2513
# 3                    AF          2  Afghanistan       2513
# 4                    AF          2  Afghanistan       2514
# ...                 ...        ...          ...        ...
# 21472                ZW        181     Zimbabwe       2948
# 21473                ZW        181     Zimbabwe       2960
# 21474                ZW        181     Zimbabwe       2960
# 21475                ZW        181     Zimbabwe       2961
# 21476                ZW        181     Zimbabwe       2928
#
#                            Item  Element Code Element         Unit  latitude  \
# 0            Wheat and products          5142    Food  1000 tonnes     33.94
# 1      Rice (Milled Equivalent)          5142    Food  1000 tonnes     33.94
# ...

# %%
data.head
# Out:
# <bound method NDFrame.head of       Area Abbreviation  Area Code         Area  Item Code  \
# 0                    AF          2  Afghanistan       2511
# 1                    AF          2  Afghanistan       2805
# 2                    AF          2  Afghanistan       2513
# 3                    AF          2  Afghanistan       2513
# 4                    AF          2  Afghanistan       2514
# ...                 ...        ...          ...        ...
# 21472                ZW        181     Zimbabwe       2948
# 21473                ZW        181     Zimbabwe       2960
# 21474                ZW        181     Zimbabwe       2960
# 21475                ZW        181     Zimbabwe       2961
# 21476                ZW        181     Zimbabwe       2928
#
#                            Item  Element Code Element         Unit  latitude  \
# 0            Wheat and products          5142    Food  1000 tonnes     33.94
# ...

# %%
data.head(2)
# Out:
#   Area Abbreviation  Area Code         Area  Item Code  \
# 0                AF          2  Afghanistan       2511
# 1                AF          2  Afghanistan       2805
#
#                        Item  Element Code Element         Unit  latitude  \
# 0        Wheat and products          5142    Food  1000 tonnes     33.94
# 1  Rice (Milled Equivalent)          5142    Food  1000 tonnes     33.94
#
#    longitude  ...   Y2004   Y2005   Y2006   Y2007   Y2008   Y2009   Y2010  \
# 0      67.71  ...  3249.0  3486.0  3704.0  4164.0  4252.0  4538.0  4605.0
# 1      67.71  ...   419.0   445.0   546.0   455.0   490.0   415.0   442.0
#
#     Y2011  Y2012  Y2013
# 0  4711.0   4810   4895
# 1   476.0    425    422
#
# [2 rows x 63 columns]

# %%
data.tail()
# Out:
#       Area Abbreviation  Area Code      Area  Item Code  \
# 21472                ZW        181  Zimbabwe       2948
# 21473                ZW        181  Zimbabwe       2960
# 21474                ZW        181  Zimbabwe       2960
# 21475                ZW        181  Zimbabwe       2961
# 21476                ZW        181  Zimbabwe       2928
#
#                           Item  Element Code Element         Unit  latitude  \
# 21472  Milk - Excluding Butter          5142    Food  1000 tonnes    -19.02
# 21473            Fish, Seafood          5521    Feed  1000 tonnes    -19.02
# 21474            Fish, Seafood          5142    Food  1000 tonnes    -19.02
# 21475  Aquatic Products, Other          5142    Food  1000 tonnes    -19.02
# 21476            Miscellaneous          5142    Food  1000 tonnes    -19.02
#
#        longitude  ...  Y2004  Y2005  Y2006  Y2007  Y2008  Y2009  Y2010  Y2011  \
# 21472      29.15  ...  373.0  357.0  359.0  356.0  341.0  385.0  418.0  457.0
# ...

# %%
#check the data types of columns
data.dtypes
# Out:
# Area Abbreviation     object
# Area Code              int64
# Area                  object
# Item Code              int64
# Item                  object
#                       ...
# Y2009                float64
# Y2010                float64
# Y2011                float64
# Y2012                  int64
# Y2013                  int64
# Length: 63, dtype: object

# %%
#check for null values
data.isnull().sum()
# Out:
# Area Abbreviation    121
# Area Code              0
# Area                   0
# Item Code              0
# Item                   0
#                     ...
# Y2009                104
# Y2010                104
# Y2011                104
# Y2012                  0
# Y2013                  0
# Length: 63, dtype: int64

# %%
#opt1; use 'dropna' method to drop the values in each row. New dataframe
data_noNAN=data.dropna(0)
data.noNAN.head(1)
# Out:
# C:\Users\Fer\AppData\Local\Temp/ipykernel_6976/4128836169.py:2: FutureWarning: In a future version of pandas all arguments of DataFrame.dropna will be keyword-only
#   data_noNAN=data.dropna(0)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6976/4128836169.py in <module>
#       1 #opt1; use 'dropna' method to drop the values in each row. New dataframe
#       2 data_noNAN=data.dropna(0)
# ----> 3 data.noNAN.head(1)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'noNAN'

# %%
#opt2; use 'fillna' to replace missing data
filled_data = data.fillna(0)
filled_data.head(2)
# Out:
#   Area Abbreviation  Area Code         Area  Item Code  \
# 0                AF          2  Afghanistan       2511
# 1                AF          2  Afghanistan       2805
#
#                        Item  Element Code Element         Unit  latitude  \
# 0        Wheat and products          5142    Food  1000 tonnes     33.94
# 1  Rice (Milled Equivalent)          5142    Food  1000 tonnes     33.94
#
#    longitude  ...   Y2004   Y2005   Y2006   Y2007   Y2008   Y2009   Y2010  \
# 0      67.71  ...  3249.0  3486.0  3704.0  4164.0  4252.0  4538.0  4605.0
# 1      67.71  ...   419.0   445.0   546.0   455.0   490.0   415.0   442.0
#
#     Y2011  Y2012  Y2013
# 0  4711.0   4810   4895
# 1   476.0    425    422
#
# [2 rows x 63 columns]

# %%
#opt3; to fill all NULL values with the last values
fill_last=data.fillna(method = 'ffill')
fill_last.head(2)
# Out:
#   Area Abbreviation  Area Code         Area  Item Code  \
# 0                AF          2  Afghanistan       2511
# 1                AF          2  Afghanistan       2805
#
#                        Item  Element Code Element         Unit  latitude  \
# 0        Wheat and products          5142    Food  1000 tonnes     33.94
# 1  Rice (Milled Equivalent)          5142    Food  1000 tonnes     33.94
#
#    longitude  ...   Y2004   Y2005   Y2006   Y2007   Y2008   Y2009   Y2010  \
# 0      67.71  ...  3249.0  3486.0  3704.0  4164.0  4252.0  4538.0  4605.0
# 1      67.71  ...   419.0   445.0   546.0   455.0   490.0   415.0   442.0
#
#     Y2011  Y2012  Y2013
# 0  4711.0   4810   4895
# 1   476.0    425    422
#
# [2 rows x 63 columns]

# %%
#to see the core statistics of the dataframe columns. only numbers 'float64' or 'int64'
data.describe()
# Out:
#           Area Code     Item Code  Element Code      latitude     longitude  \
# count  21477.000000  21477.000000  21477.000000  21477.000000  21477.000000
# mean     125.449411   2694.211529   5211.687154     20.450613     15.794445
# std       72.868149    148.973406    146.820079     24.628336     66.012104
# min        1.000000   2511.000000   5142.000000    -40.900000   -172.100000
# 25%       63.000000   2561.000000   5142.000000      6.430000    -11.780000
# 50%      120.000000   2640.000000   5142.000000     20.590000     19.150000
# 75%      188.000000   2782.000000   5142.000000     41.150000     46.870000
# max      276.000000   2961.000000   5521.000000     64.960000    179.410000
#
#                Y1961          Y1962          Y1963          Y1964  \
# count   17938.000000   17938.000000   17938.000000   17938.000000
# mean      195.262069     200.782250     205.464600     209.925577
# std      1864.124336    1884.265591    1861.174739    1862.000116
# ...

# %%
##To select and manipulate data (columns)

# %%
#selecting 1 column to display - examples 'area'. [] important to use
data['Area'].head(100)
# Out:
# 0     Afghanistan
# 1     Afghanistan
# 2     Afghanistan
# 3     Afghanistan
# 4     Afghanistan
#          ...
# 95        Albania
# 96        Albania
# 97        Albania
# 98        Albania
# 99        Albania
# Name: Area, Length: 100, dtype: object

# %%
data['Item'].head(3)
# Out:
# 0          Wheat and products
# 1    Rice (Milled Equivalent)
# 2         Barley and products
# Name: Item, dtype: object

# %%
#there are 2 options to display multiple columns; DOUBLE []
#option 1. use colimns names in ''

data[['Area', 'Y1961','Y1962']].head(3)
# Out:
#           Area   Y1961   Y1962
# 0  Afghanistan  1928.0  1904.0
# 1  Afghanistan   183.0   183.0
# 2  Afghanistan    76.0    76.0

# %%
#opt2; use 'iloc' to displau multiple columns using column numbers

data.iloc[:, [2,10,11]]
# Out:
#               Area   Y1961   Y1962
# 0      Afghanistan  1928.0  1904.0
# 1      Afghanistan   183.0   183.0
# 2      Afghanistan    76.0    76.0
# 3      Afghanistan   237.0   237.0
# 4      Afghanistan   210.0   210.0
# ...            ...     ...     ...
# 21472     Zimbabwe   230.0   232.0
# 21473     Zimbabwe    27.0    25.0
# 21474     Zimbabwe     6.0     6.0
# 21475     Zimbabwe     0.0     0.0
# 21476     Zimbabwe     0.0     0.0
#
# [21477 rows x 3 columns]

# %%
#total sum of the column values for year 2013
data['Y2013'].sum()
# Out:
# 12361248

# %%
#total mean (average) of the column values for 2013
data['Y2013'].mean()
# Out:
# 575.5574800949853

# %%
##To Select and manipulate data (rows)

# %%
#Rows in dataframes are selected using 2 methods
#opt1; use iloc

data.iloc[0:10, :].head(2)
# Out:
#   Area Abbreviation  Area Code         Area  Item Code  \
# 0                AF          2  Afghanistan       2511
# 1                AF          2  Afghanistan       2805
#
#                        Item  Element Code Element         Unit  latitude  \
# 0        Wheat and products          5142    Food  1000 tonnes     33.94
# 1  Rice (Milled Equivalent)          5142    Food  1000 tonnes     33.94
#
#    longitude  ...   Y2004   Y2005   Y2006   Y2007   Y2008   Y2009   Y2010  \
# 0      67.71  ...  3249.0  3486.0  3704.0  4164.0  4252.0  4538.0  4605.0
# 1      67.71  ...   419.0   445.0   546.0   455.0   490.0   415.0   442.0
#
#     Y2011  Y2012  Y2013
# 0  4711.0   4810   4895
# 1   476.0    425    422
#
# [2 rows x 63 columns]

# %%
#opt2; use statements to select rows with "column name" == "row" name
#this example selects rows where area = 'ireland'

data[data['Area'] == 'Ireland']
# Out:
#      Area Abbreviation  Area Code     Area  Item Code  \
# 9533                IE        104  Ireland       2511
# 9534                IE        104  Ireland       2511
# 9535                IE        104  Ireland       2805
# 9536                IE        104  Ireland       2805
# 9537                IE        104  Ireland       2513
# ...                ...        ...      ...        ...
# 9664                IE        104  Ireland       2948
# 9665                IE        104  Ireland       2948
# 9666                IE        104  Ireland       2960
# 9667                IE        104  Ireland       2960
# 9668                IE        104  Ireland       2961
#
#                           Item  Element Code Element         Unit  latitude  \
# 9533        Wheat and products          5521    Feed  1000 tonnes     53.41
# 9534        Wheat and products          5142    Food  1000 tonnes     53.41
# 9535  Rice (Milled Equivalent)          5521    Feed  1000 tonnes     53.41
# ...

# %%
ireland_production = data[data['Area'] == 'Ireland']
ireland_production.head(2)
# Out:
#      Area Abbreviation  Area Code     Area  Item Code                Item  \
# 9533                IE        104  Ireland       2511  Wheat and products
# 9534                IE        104  Ireland       2511  Wheat and products
#
#       Element Code Element         Unit  latitude  longitude  ...  Y2004  \
# 9533          5521    Feed  1000 tonnes     53.41      -8.24  ...  968.0
# 9534          5142    Food  1000 tonnes     53.41      -8.24  ...  395.0
#
#       Y2005  Y2006  Y2007   Y2008  Y2009  Y2010  Y2011  Y2012  Y2013
# 9533  976.0  902.0  685.0  1063.0  804.0  783.0  760.0    650    600
# 9534  423.0  501.0  449.0   470.0  493.0  512.0  502.0    494    500
#
# [2 rows x 63 columns]

# %%
ireland_fish = data[(data['Area'] == 'Ireland') & (data['Item'] == 'Fish, Seafood')]
ireland_fish.head()
# Out:
#      Area Abbreviation  Area Code     Area  Item Code           Item  \
# 9666                IE        104  Ireland       2960  Fish, Seafood
# 9667                IE        104  Ireland       2960  Fish, Seafood
#
#       Element Code Element         Unit  latitude  longitude  ...  Y2004  \
# 9666          5521    Feed  1000 tonnes     53.41      -8.24  ...    0.0
# 9667          5142    Food  1000 tonnes     53.41      -8.24  ...   95.0
#
#       Y2005  Y2006  Y2007  Y2008  Y2009  Y2010  Y2011  Y2012  Y2013
# 9666   22.0   29.0   66.0   43.0  111.0  112.0  112.0    112    112
# 9667   94.0   87.0   97.0   92.0   99.0  102.0  102.0    102    102
#
# [2 rows x 63 columns]

# %%
##Deleting rows and columns (drop)

# %%
#to delete columns in a dataframe "axis=1" signifier for columns.
#example shows how to delete the "item code" column from the dataframe

data = data.drop('Item Code', axis=1)
data.head(2)
# Out:
#   Area Abbreviation  Area Code         Area                      Item  \
# 0                AF          2  Afghanistan        Wheat and products
# 1                AF          2  Afghanistan  Rice (Milled Equivalent)
#
#    Element Code Element         Unit  latitude  longitude   Y1961  ...  \
# 0          5142    Food  1000 tonnes     33.94      67.71  1928.0  ...
# 1          5142    Food  1000 tonnes     33.94      67.71   183.0  ...
#
#     Y2004   Y2005   Y2006   Y2007   Y2008   Y2009   Y2010   Y2011  Y2012  \
# 0  3249.0  3486.0  3704.0  4164.0  4252.0  4538.0  4605.0  4711.0   4810
# 1   419.0   445.0   546.0   455.0   490.0   415.0   442.0   476.0    425
#
#    Y2013
# 0   4895
# 1    422
#
# [2 rows x 62 columns]

# %%
#delete rows 

data = data.drop([0,1], axis = 0)
data.head(2)
# Out:
#   Area Abbreviation  Area Code         Area                 Item  \
# 2                AF          2  Afghanistan  Barley and products
# 3                AF          2  Afghanistan  Barley and products
#
#    Element Code Element         Unit  latitude  longitude  Y1961  ...  Y2004  \
# 2          5521    Feed  1000 tonnes     33.94      67.71   76.0  ...   58.0
# 3          5142    Food  1000 tonnes     33.94      67.71  237.0  ...  185.0
#
#    Y2005  Y2006  Y2007  Y2008  Y2009  Y2010  Y2011  Y2012  Y2013
# 2  236.0  262.0  263.0  230.0  379.0  315.0  203.0    367    360
# 3   43.0   44.0   48.0   62.0   55.0   60.0   72.0     78     89
#
# [2 rows x 62 columns]

# %%
#rename the area column to 'Element'
data = data.rename(columns=("Element": "Category"))
data.head(2)
# Out:
#   File "C:\Users\Fer\AppData\Local\Temp/ipykernel_6976/648791684.py", line 2
#     data = data.rename(columns=("Element": "Category"))
#                                          ^
# SyntaxError: invalid syntax

# %% [markdown]
# ###Working with data

# %%
ireland_data = data[data["Area Abbreviation"] == "IE"]
ireland_data.head(5)
# Out:
#      Area Abbreviation  Area Code     Area                      Item  \
# 9533                IE        104  Ireland        Wheat and products
# 9534                IE        104  Ireland        Wheat and products
# 9535                IE        104  Ireland  Rice (Milled Equivalent)
# 9536                IE        104  Ireland  Rice (Milled Equivalent)
# 9537                IE        104  Ireland       Barley and products
#
#       Element Code Element         Unit  latitude  longitude  Y1961  ...  \
# 9533          5521    Feed  1000 tonnes     53.41      -8.24  132.0  ...
# 9534          5142    Food  1000 tonnes     53.41      -8.24  389.0  ...
# 9535          5521    Feed  1000 tonnes     53.41      -8.24    0.0  ...
# 9536          5142    Food  1000 tonnes     53.41      -8.24    2.0  ...
# 9537          5521    Feed  1000 tonnes     53.41      -8.24  322.0  ...
#
#       Y2004  Y2005   Y2006  Y2007   Y2008   Y2009   Y2010   Y2011  Y2012  \
# ...
