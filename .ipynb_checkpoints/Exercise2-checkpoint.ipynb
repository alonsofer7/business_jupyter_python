# %%
import pandas as pd
import numpy as np

#from pandas import Series, Dataframe

# %%
df = pd.read_csv('sales_null.csv', encoding = 'latin1')
df.head()
# Out:
#                               Region                Country        Item Type  \
# 0              Australia and Oceania                 Tuvalu        Baby Food
# 1  Central America and the Caribbean                Grenada           Cereal
# 2                             Europe                 Russia  Office Supplies
# 3                 Sub-Saharan Africa  Sao Tome and Principe           Fruits
# 4                 Sub-Saharan Africa                 Rwanda  Office Supplies
#
#   Sales Channel Order Priority  Order Date     Order ID   Ship Date  \
# 0       Offline              H   5/28/2010  669165933.0   6/27/2010
# 1        Online              C   8/22/2012  963881480.0   9/15/2012
# 2       Offline              L  05/02/2014  341417157.0  05/08/2014
# 3        Online              C   6/20/2014  514321792.0  07/05/2014
# 4       Offline              L  02/01/2013  115456712.0  02/06/2013
#
#    Units Sold  Unit Price  Unit Cost  Total Revenue  Total Cost
# ...

# %%
df.dtypes
# Out:
# Region             object
# Country            object
# Item Type          object
# Sales Channel      object
# Order Priority     object
# Order Date         object
# Order ID          float64
# Ship Date          object
# Units Sold        float64
# Unit Price        float64
# Unit Cost         float64
# Total Revenue     float64
# Total Cost        float64
# dtype: object

# %%
df.isnull().sum()
# Out:
# Region             0
# Country            0
# Item Type          0
# Sales Channel      0
# Order Priority     0
# Order Date         0
# Order ID           7
# Ship Date          0
# Units Sold        82
# Unit Price         0
# Unit Cost          0
# Total Revenue      5
# Total Cost         0
# dtype: int64

# %%
df1 = df.fillna(0)
df1.head(3)
# Out:
#                               Region  Country        Item Type Sales Channel  \
# 0              Australia and Oceania   Tuvalu        Baby Food       Offline
# 1  Central America and the Caribbean  Grenada           Cereal        Online
# 2                             Europe   Russia  Office Supplies       Offline
#
#   Order Priority  Order Date     Order ID   Ship Date  Units Sold  Unit Price  \
# 0              H   5/28/2010  669165933.0   6/27/2010      9925.0      255.28
# 1              C   8/22/2012  963881480.0   9/15/2012      2804.0      205.70
# 2              L  05/02/2014  341417157.0  05/08/2014      1779.0      651.21
#
#    Unit Cost  Total Revenue  Total Cost
# 0     159.42      2533654.0  1582243.50
# 1     117.11            0.0   328376.44
# 2     524.96            0.0   933903.84

# %%
pd.options.display.float_format = '{:.2f}'.format
df1
# Out:
#                                Region                Country        Item Type  \
# 0               Australia and Oceania                 Tuvalu        Baby Food
# 1   Central America and the Caribbean                Grenada           Cereal
# 2                              Europe                 Russia  Office Supplies
# 3                  Sub-Saharan Africa  Sao Tome and Principe           Fruits
# 4                  Sub-Saharan Africa                 Rwanda  Office Supplies
# ..                                ...                    ...              ...
# 95                 Sub-Saharan Africa                   Mali          Clothes
# 96                               Asia               Malaysia           Fruits
# 97                 Sub-Saharan Africa           Sierra Leone       Vegetables
# 98                      North America                 Mexico    Personal Care
# 99                 Sub-Saharan Africa             Mozambique        Household
#
# ...

# %%
df1['Units Sold'] = df1['Units Sold'].astype(int) 
df1['Units Sold'].head(3)
# Out:
#   File "C:\Users\Fer\AppData\Local\Temp/ipykernel_11756/2781813289.py", line 1
#     df1['Units Sold'] = df1['Units Sold'].astype(int) df1['Units Sold'].head(3)
#                                                       ^
# SyntaxError: invalid syntax

# %%
df1.head(2)
# Out:
#                               Region  Country  Item Type Sales Channel  \
# 0              Australia and Oceania   Tuvalu  Baby Food       Offline
# 1  Central America and the Caribbean  Grenada     Cereal        Online
#
#   Order Priority Order Date     Order ID  Ship Date  Units Sold  Unit Price  \
# 0              H  5/28/2010 669165933.00  6/27/2010        9925      255.28
# 1              C  8/22/2012 963881480.00  9/15/2012        2804      205.70
#
#    Unit Cost  Total Revenue  Total Cost
# 0     159.42     2533654.00  1582243.50
# 1     117.11           0.00   328376.44

# %%
#Create a new calculated column called 'Total Profit'
Total_Profit = df1['Total Profit'].sum()
print ('Total Profit =', Total_Profit)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Total Profit'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
#To create a sum of all profits.
Total_Profit = df1['Total Profit'].sum()
print ('Total Profit =', Total_Profit)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Total Profit'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
#To sort the values Highest to Lowest in Total Profit
profits = df1['Total Profit'].sort_values(ascending=False)
print ('Total Profits =', profits)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Total Profit'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
#To use groupby
df1.groupby(['Region'])
print (df1.groupby('Region').groups)
# Out:
# {'Asia': [10, 12, 14, 16, 18, 33, 38, 44, 70, 77, 96], 'Australia and Oceania': [0, 5, 19, 23, 26, 32, 56, 60, 76, 79, 91], 'Central America and the Caribbean': [1, 13, 22, 35, 64, 67, 94], 'Europe': [2, 15, 20, 21, 24, 25, 28, 30, 39, 43, 46, 47, 48, 50, 57, 58, 61, 68, 78, 80, 89, 93], 'Middle East and North Africa': [36, 41, 52, 63, 71, 74, 81, 82, 88, 92], 'North America': [75, 85, 98], 'Sub-Saharan Africa': [3, 4, 6, 7, 8, 9, 11, 17, 27, 29, 31, 34, 37, 40, 42, 45, 49, 51, 53, 54, 55, 59, 62, 65, 66, 69, 72, 73, 83, 84, 86, 87, 90, 95, 97, 99]}

# %%
#To use groupby (by lowest Total Revenue first)
df1.groupby(['Region']).sum().sort_values('Total Revenue', ascending = True)
# Out:
#                                         Order ID  Units Sold  Unit Price  \
# Region
# North America                      1976778136.00        5767      831.73
# Central America and the Caribbean  4492273876.00       10960     1702.21
# Australia and Oceania              4414169747.00       22288     2449.40
# Middle East and North Africa       5028923195.00        2543     2415.06
# Asia                               3644119163.00        6267     3693.90
# Europe                            11884002711.00       14349     7237.55
# Sub-Saharan Africa                19175785450.00       21852     9346.28
#
#                                    Unit Cost  Total Revenue  Total Cost
# Region
# North America                         615.88     5643356.55  4185413.79
# Central America and the Caribbean    1104.72     8593602.69  6323477.64
# Australia and Oceania                1702.19    13335062.41  9372105.10
# Middle East and North Africa         1524.50    14052706.58  8291514.72
# ...

# %%
#To use groupby (by lowest Total Revenue first)
df1.groupby(['Region']).sum().sort_values('Total Revenue', ascending = False).head(10)
# Out:
#                                         Order ID  Units Sold  Unit Price  \
# Region
# Sub-Saharan Africa                19175785450.00       21852     9346.28
# Europe                            11884002711.00       14349     7237.55
# Asia                               3644119163.00        6267     3693.90
# Middle East and North Africa       5028923195.00        2543     2415.06
# Australia and Oceania              4414169747.00       22288     2449.40
# Central America and the Caribbean  4492273876.00       10960     1702.21
# North America                      1976778136.00        5767      831.73
#
#                                    Unit Cost  Total Revenue  Total Cost
# Region
# Sub-Saharan Africa                   6612.39    36300014.75 27488820.03
# Europe                               4909.66    32210429.52 22285993.48
# Asia                                 2635.46    21347091.02 15233245.15
# Middle East and North Africa         1524.50    14052706.58  8291514.72
# ...

# %%
#To use groupby (by lowest Total Revenue first)
Revenue_Table = df1.groupby(['Region']).sum().sort_values('Total Revenue', ascending = False)
Revenue_Table[['Total Revenue', 'Total Cost']]
# Out:
#                                    Total Revenue  Total Cost
# Region
# Sub-Saharan Africa                   36300014.75 27488820.03
# Europe                               32210429.52 22285993.48
# Asia                                 21347091.02 15233245.15
# Middle East and North Africa         14052706.58  8291514.72
# Australia and Oceania                13335062.41  9372105.10
# Central America and the Caribbean     8593602.69  6323477.64
# North America                         5643356.55  4185413.79

# %%
#To query method to except specific data.
Revenue_Table.query('Region ==["Asia"]')
